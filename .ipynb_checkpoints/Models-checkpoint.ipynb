# %%
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 

from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate, train_test_split

# %%
Plant_Dataset = pd.read_csv('Feature_Extracted_Plant_Dataset.csv')
Plant_Dataset.describe()
# Out:
#          Edge_Count  Re(Mean_Frequency)  Im(Mean_Frequency)  \
# count  52803.000000        52803.000000        5.280300e+04
# mean     441.175104            0.432590       -4.128050e-20
# std      190.125086            0.133243        2.009960e-17
# min        0.000000            0.000848       -1.665335e-16
# 25%      289.000000            0.342362       -1.387779e-17
# 50%      420.000000            0.436709        0.000000e+00
# 75%      581.000000            0.522776        1.387779e-17
# max     1569.000000            0.981226        1.110223e-16
#
#        Frequency_Variance  StDev_Contrast    Mean_Noise   StDev_Noise  \
# count        52803.000000    52803.000000  52803.000000  52803.000000
# mean          1043.109380        0.142318      0.476966      0.142318
# std            301.178560        0.042527      0.071808      0.042527
# min            163.408944        0.029202      0.131723      0.029202
# 25%            842.672999        0.111821      0.430708      0.111821
# 50%           1006.582372        0.140735      0.474295      0.140735
# 75%           1191.774667        0.169974      0.516459      0.169974
# max           3588.441038        0.363226      0.925371      0.363226
#
#        Minimum_Intensity  Maximum_Intensity
# count       52803.000000       52803.000000
# mean            0.085437           0.753024
# std             0.062764           0.094796
# min             0.000000           0.367933
# 25%             0.040853           0.688573
# 50%             0.069160           0.758271
# 75%             0.115961           0.820833
# max             0.575310           1.000000

# %% [markdown]
# #### Correlation Heatmap ####

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(Plant_Dataset.select_dtypes(['float64']).corr(), annot=True)
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation')

# %%
def plot_feature_importance(model):
    n_features = Plant_Dataset.shape[1] - 2
    plt.barh(np.arange(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), Plant_Dataset.drop(columns=['Disease', 'Is_Healthy']).columns)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.ylim(-1, n_features)

    model.feature_importances_

# %% [markdown]
# ## Train to Identify Specific Disease ##

# %%
Label_Encoder = LabelEncoder()

X = Plant_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Plant_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

num_classes = len(Label_Encoder.classes_)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
XGBoost = XGBClassifier(n_estimators=64, max_depth=4, learning_rate=0.2).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(XGBoost.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(XGBoost.score(X_test, Y_test)))

plot_feature_importance(XGBoost)
# Out:
# Accuracy on training set: 0.489
# Accuracy on test set: 0.447

# %% [markdown]
# ## Train to Detect Healthy vs Unhealthy ##

# %%
X = Plant_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Plant_Dataset.Is_Healthy

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
XGBoost = XGBClassifier(n_estimators=64, max_depth=5, learning_rate=0.2).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(XGBoost.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(XGBoost.score(X_test, Y_test)))

plot_feature_importance(XGBoost)
# Out:
# Accuracy on training set: 0.826
# Accuracy on test set: 0.811

# %% [markdown]
# ## Train on Specific Plant to Reduce Generalization ##
# #### 1.) Apples ####

# %%
Apple_Dataset = pd.read_csv('Individual Plant Datasets/Apple.csv', index_col=0)
Apple_Dataset.describe()
# Out:
#         Edge_Count  Re(Mean_Frequency)  Im(Mean_Frequency)  \
# Apple___healthy_image (974).JPG                   731.207950        0.111116
#
#                                           Mean_Noise  StDev_Noise  \
# Apple___Cedar_apple_rust_image (263).JPG    0.526734     0.104107
# Apple___Cedar_apple_rust_image (234).JPG    0.537653     0.073736
# Apple___Cedar_apple_rust_image (222).JPG    0.554713     0.146356
# Apple___Cedar_apple_rust_image (275).JPG    0.525948     0.087797
# Apple___Cedar_apple_rust_image (71).JPG     0.558878     0.103372
# ...                                              ...          ...
# Apple___healthy_image (562).JPG             0.512577     0.122171
# Apple___healthy_image (64).JPG              0.468747     0.134761
# Apple___healthy_image (1200).JPG            0.436404     0.162524
# Apple___healthy_image (427).JPG             0.654864     0.236639
# Apple___healthy_image (974).JPG             0.407672     0.111116
#
#                                           Minimum_Intensity  \
# Apple___Cedar_apple_rust_image (263).JPG           0.074465
# Apple___Cedar_apple_rust_image (234).JPG           0.192641
# Apple___Cedar_apple_rust_image (222).JPG           0.024333
# Apple___Cedar_apple_rust_image (275).JPG           0.267478
# Apple___Cedar_apple_rust_image (71).JPG            0.186533
# ...                                                     ...
# Apple___healthy_image (562).JPG                    0.196822
# Apple___healthy_image (64).JPG                     0.081445
# Apple___healthy_image (1200).JPG                   0.069978
# Apple___healthy_image (427).JPG                    0.098949
# Apple___healthy_image (974).JPG                    0.023149
#
#                                           Maximum_Intensity  Is_Healthy  \
# Apple___Cedar_apple_rust_image (263).JPG           0.791481       False
# Apple___Cedar_apple_rust_image (234).JPG           0.755704       False
# Apple___Cedar_apple_rust_image (222).JPG           0.790669       False
# Apple___Cedar_apple_rust_image (275).JPG           0.809190       False
# Apple___Cedar_apple_rust_image (71).JPG            0.816386       False
# ...                                                     ...         ...
# Apple___healthy_image (562).JPG                    0.802163        True
# Apple___healthy_image (64).JPG                     0.645125        True
# Apple___healthy_image (1200).JPG                   0.684883        True
# Apple___healthy_image (427).JPG                    0.914789        True
# Apple___healthy_image (974).JPG                    0.623895        True
#
#                                                                      Disease
# Apple___Cedar_apple_rust_image (263).JPG  Leaf_blight_(Isariopsis_Leaf_Spot)
# Apple___Cedar_apple_rust_image (234).JPG  Leaf_blight_(Isariopsis_Leaf_Spot)
# Apple___Cedar_apple_rust_image (222).JPG  Leaf_blight_(Isariopsis_Leaf_Spot)
# Apple___Cedar_apple_rust_image (275).JPG  Leaf_blight_(Isariopsis_Leaf_Spot)
# Apple___Cedar_apple_rust_image (71).JPG   Leaf_blight_(Isariopsis_Leaf_Spot)
# ...                                                                      ...
# Apple___healthy_image (562).JPG                                      Healthy
# Apple___healthy_image (64).JPG                                       Healthy
# Apple___healthy_image (1200).JPG                                     Healthy
# Apple___healthy_image (427).JPG                                      Healthy
# Apple___healthy_image (974).JPG                                      Healthy
#
# [3171 rows x 11 columns]

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(Apple_Dataset.select_dtypes(['float64']).corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation')

# %%
Label_Encoder = LabelEncoder()

X = Apple_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Apple_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
XGBoost = XGBClassifier(n_estimators=64, max_depth=4, learning_rate=0.1).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(XGBoost.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(XGBoost.score(X_test, Y_test)))

plot_feature_importance(XGBoost)
# Out:
# Accuracy on training set: 0.690
# Accuracy on test set: 0.499

# %% [markdown]
# #### Cherries ####

# %%
Cherry_Dataset = pd.read_csv('Individual Plant Datasets/Cherry.csv', index_col=0)
Cherry_Dataset.describe()
# Out:
#         Edge_Count  Re(Mean_Frequency)  Im(Mean_Frequency)  \
# count  1906.000000         1906.000000        1.906000e+03
# mean    389.244491            0.464820       -6.228759e-20
# std     149.367876            0.118315        1.689068e-17
# min      61.000000            0.067233       -6.938894e-17
# 25%     266.000000            0.387358       -1.040834e-17
# 50%     347.000000            0.456479        0.000000e+00
# 75%     503.000000            0.536286        1.040834e-17
# max    1569.000000            0.926562        6.938894e-17
#
#        Frequency_Variance  StDev_Contrast   Mean_Noise  StDev_Noise  \
# count         1906.000000     1906.000000  1906.000000  1906.000000
# mean          1149.349275        0.121298     0.508949     0.121298
# std            349.629854        0.025664     0.079130     0.025664
# min            370.530117        0.051573     0.290424     0.051573
# 25%            920.616747        0.104626     0.456112     0.104626
# 50%           1077.787155        0.120679     0.496824     0.120679
# 75%           1321.233339        0.137360     0.554726     0.137360
# max           2730.557121        0.229856     0.807108     0.229856
#
#        Minimum_Intensity  Maximum_Intensity
# count        1906.000000        1906.000000
# mean            0.106022           0.771644
# std             0.073519           0.073970
# min             0.000565           0.528842
# 25%             0.042633           0.720882
# 50%             0.091830           0.759824
# 75%             0.153921           0.823013
# max             0.401117           1.000000

# %%
Cherry_Dataset
# Out:
#                                           Edge_Count  Re(Mean_Frequency)  \
# Cherry___Powdery_mildew_image (776).JPG          610            0.474783
# Cherry___Powdery_mildew_image (326).JPG          528            0.668742
# Cherry___Powdery_mildew_image (633).JPG          507            0.580713
# Cherry___Powdery_mildew_image (1014).JPG         600            0.559703
# Cherry___Powdery_mildew_image (263).JPG          575            0.221903
# ...                                              ...                 ...
# Cherry___healthy_image (831).JPG                 286            0.469031
# Cherry___healthy_image (132).JPG                 236            0.531256
# Cherry___healthy_image (562).JPG                 289            0.499542
# Cherry___healthy_image (64).JPG                  303            0.380247
# Cherry___healthy_image (427).JPG                 236            0.671316
#
#                                           Im(Mean_Frequency)  \
# Cherry___Powdery_mildew_image (776).JPG        -1.561251e-17
# Cherry___Powdery_mildew_image (326).JPG         2.081668e-17
# Cherry___Powdery_mildew_image (633).JPG        -6.938894e-18
# Cherry___Powdery_mildew_image (1014).JPG        2.775558e-17
# Cherry___Powdery_mildew_image (263).JPG         1.387779e-17
# ...                                                      ...
# Cherry___healthy_image (831).JPG                3.469447e-18
# Cherry___healthy_image (132).JPG                6.938894e-18
# Cherry___healthy_image (562).JPG                1.734723e-17
# Cherry___healthy_image (64).JPG                 3.469447e-18
# Cherry___healthy_image (427).JPG                0.000000e+00
#
#                                           Frequency_Variance  StDev_Contrast  \
# Cherry___Powdery_mildew_image (776).JPG          1070.194082        0.118539
# Cherry___Powdery_mildew_image (326).JPG          1358.034662        0.123002
r(), annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation')

# %%
Label_Encoder = LabelEncoder()

X = Cherry_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Cherry_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
XGBoost = XGBClassifier(n_estimators=32, max_depth=4, learning_rate=0.1).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(XGBoost.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(XGBoost.score(X_test, Y_test)))

plot_feature_importance(XGBoost)
# Out:
# Accuracy on training set: 0.835
# Accuracy on test set: 0.788

# %% [markdown]
# ## Train to Identify Specific Disease - Using Random Forest Classifier

# %%
Label_Encoder = LabelEncoder()

X = Plant_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Plant_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

num_classes = len(Label_Encoder.classes_)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
RandomForest = RandomForestClassifier(n_estimators=64, max_depth=4, random_state=42).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(RandomForest.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(RandomForest.score(X_test, Y_test)))

plot_feature_importance(RandomForest)
# Out:
# Accuracy on training set: 0.370
# Accuracy on test set: 0.368

# %% [markdown]
# ## Train to Detect Healthy or Unhealthy

# %%
X = Plant_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Plant_Dataset.Is_Healthy

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
RandomForest = RandomForestClassifier(n_estimators=64, max_depth=5, random_state=42).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(RandomForest.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(RandomForest.score(X_test, Y_test)))

plot_feature_importance(RandomForest)
# Out:
# Accuracy on training set: 0.799
# Accuracy on test set: 0.796

# %% [markdown]
# ## Train on Specific Plant to Reduce Generalization
# #### 1.) Apples

# %%
Apple_Dataset = pd.read_csv('Individual Plant Datasets/Apple.csv', index_col=0)

# %%
Label_Encoder = LabelEncoder()

X = Apple_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Apple_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
RandomForest = RandomForestClassifier(n_estimators=64, max_depth=4, random_state=42).fit(X_train, Y_train)

print("Accuracy on training set: {:.3f}".format(RandomForest.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(RandomForest.score(X_test, Y_test)))

plot_feature_importance(RandomForest)
# Out:
# Accuracy on training set: 0.533
# Accuracy on test set: 0.498

# %% [markdown]
# #### 2.) Cherries

# %%
Cherry_Dataset = pd.read_csv('Individual Plant Datasets/Cherry.csv', index_col=0)

# %%
Label_Encoder = LabelEncoder()

X = Cherry_Dataset.drop(columns=['Disease', 'Is_Healthy'])
Y = Cherry_Dataset.Disease
Y = Label_Encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
RandomForest = RandomForestClassifier(n_estimators=64, max_depth=7, random_state=42).fit(X_train, Y_train) # max depth increased to 7

print("Accuracy on training set: {:.3f}".format(RandomForest.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(RandomForest.score(X_test, Y_test)))

plot_feature_importance(RandomForest)
# Out:
# Accuracy on training set: 0.879
# Accuracy on test set: 0.775
